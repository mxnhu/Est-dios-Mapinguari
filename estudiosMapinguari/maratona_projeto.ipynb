# %%
# primeiro importa o csv
import pandas as pd

uri = 'https://raw.githubusercontent.com/Cogitus/Est-dios-Mapinguari/master/Tabela%2BReferencia%2BAuditoria%2Bde%2BObras%2BP%C3%BAblicas%2B-%2BAN%C3%81LISE%2BAVAN%C3%87ADA%2B-%2B03%2BEMPRESAS%20-%20Custo%20UnitxQuant%20(Input).csv'

# %%
#importando para um objeto Pandas

dados = pd.read_csv(uri)
dados.head()
# Out:
#    ITEM    REFORMA DA PRAÇA MUNICIPAL SÃO JOÃO BATISTA UND.  QUANT.  \
# 0   NaN                                  1 DEMOLIÇÕES   NaN     NaN
# 1   1.1  Demolição de revestimentos de pedras naturais   m²    15.0
# 2   1.2  Demolição de revestimentos de pedras naturais   m²    16.0
# 3   1.3  Demolição de revestimentos de pedras naturais   m²    17.0
# 4   1.4  Demolição de revestimentos de pedras naturais   m²    18.0
#
#   PRECO_UNIT  PRECO_UNIT_1  PRECO_UNIT_2  PRECO_UNIT_3
# 0        NaN           NaN           NaN           NaN
# 1      18.90         18.70         18.25         18.35
# 2      18.80         18.65         18.20         18.30
# 3      18.70         18.60         18.15         18.25
# 4      18.60         18.55         18.10         18.20

# %%
# elimina os NaN

dados = dados.dropna()

# %%
#so visualização, apagar depois

dados
# Out:
#       ITEM        REFORMA DA PRAÇA MUNICIPAL SÃO JOÃO BATISTA UND.  QUANT.  \
# 1     1.10      Demolição de revestimentos de pedras naturais   m²    15.0
# 2     1.20      Demolição de revestimentos de pedras naturais   m²    16.0
# 3     1.30      Demolição de revestimentos de pedras naturais   m²    17.0
# 4     1.40      Demolição de revestimentos de pedras naturais   m²    18.0
# 5     1.50      Demolição de revestimentos de pedras naturais   m²    19.0
# 6     1.60      Demolição de revestimentos de pedras naturais   m²    20.0
# 7     1.70      Demolição de revestimentos de pedras naturais   m²    21.0
# 8     1.80      Demolição de revestimentos de pedras naturais   m²    22.0
# 9     1.90      Demolição de revestimentos de pedras naturais   m²    23.0
# 10    1.10      Demolição de revestimentos de pedras naturais   m²    24.0
# 11    1.11      Demolição de revestimentos de pedras naturais   m²    25.0
# 12    1.12      Demolição de revestimentos de pedras naturais   m²    26.0
# 13    1.13      Demolição de revestimentos de pedras naturais   m²    27.0
# 14    1.14      Demolição de revestimentos de pedras naturais   m²    28.0
# 15    1.15      Demolição de revestimentos de pedras naturais   m²    29.0
# 16    1.16      Demolição de revestimentos de pedras naturais   m²    30.0
# 17    1.17      Demolição de revestimentos de pedras naturais   m²    31.0
# 18    1.18      Demolição de revestimentos de pedras naturais   m²    32.0
# 19    1.19      Demolição de revestimentos de pedras naturais   m²    33.0
# 20    1.20      Demolição de revestimentos de pedras naturais   m²    34.0
# 22    2.10                              Regularização da obra   m²   900.0
# 23    2.20                              Regularização da obra   m²   910.0
# 24    2.30                              Regularização da obra   m²   920.0
# 25    2.40                              Regularização da obra   m²   930.0
# 26    2.50                              Regularização da obra   m²   940.0
# 27    2.60                              Regularização da obra   m²   950.0
# 28    2.70                              Regularização da obra   m²   960.0
# 29    2.80                              Regularização da obra   m²   970.0
# 30    2.90                              Regularização da obra   m²   980.0
# 31    2.10                              Regularização da obra   m²   990.0
# ..     ...                                                ...  ...     ...
# 200  10.11  Pintura látex acrílica ambientes internos e ex...   m²    40.0
# 201  10.12  Pintura látex acrílica ambientes internos e ex...   m²    41.0
# 202  10.13  Pintura látex acrílica ambientes internos e ex...   m²    42.0
# 203  10.14  Pintura látex acrílica ambientes internos e ex...   m²    43.0
# 204  10.15  Pintura látex acrílica ambientes internos e ex...   m²    44.0
# 205  10.16  Pintura látex acrílica ambientes internos e ex...   m²    45.0
# 206  10.17  Pintura látex acrílica ambientes internos e ex...   m²    46.0
# 207  10.18  Pintura látex acrílica ambientes internos e ex...   m²    47.0
# 208  10.19  Pintura látex acrílica ambientes internos e ex...   m²    48.0
# 209  10.20  Pintura látex acrílica ambientes internos e ex...   m²    49.0
# 211  11.10                           Grama batatais em placas   m²    20.0
# 212  11.20                           Grama batatais em placas   m²    21.0
# 213  11.30                           Grama batatais em placas   m²    22.0
# 214  11.40                           Grama batatais em placas   m²    23.0
# 215  11.50                           Grama batatais em placas   m²    24.0
# 216  11.60                           Grama batatais em placas   m²    25.0
# 217  11.70                           Grama batatais em placas   m²    26.0
# 218  11.80                           Grama batatais em placas   m²    27.0
# 219  11.90                           Grama batatais em placas   m²    28.0
# 220  11.10                           Grama batatais em placas   m²    29.0
# 221  11.11                           Grama batatais em placas   m²    30.0
# 222  11.12                           Grama batatais em placas   m²    31.0
# 223  11.13                           Grama batatais em placas   m²    32.0
# 224  11.14                           Grama batatais em placas   m²    33.0
# 225  11.15                           Grama batatais em placas   m²    34.0
# 226  11.16                           Grama batatais em placas   m²    35.0
# 227  11.17                           Grama batatais em placas   m²    36.0
# 228  11.18                           Grama batatais em placas   m²    37.0
# 229  11.19                           Grama batatais em placas   m²    38.0
# 230  11.20                           Grama batatais em placas   m²    39.0
#
#     PRECO_UNIT  PRECO_UNIT_1  PRECO_UNIT_2  PRECO_UNIT_3
# 1        18.90         18.70         18.25         18.35
# 2        18.80         18.65         18.20         18.30
# 3        18.70         18.60         18.15         18.25
# 4        18.60         18.55         18.10         18.20
# 5        18.50         18.50         18.05         18.15
# 6        18.40         18.45         18.00         18.10
# 7        18.30         18.40         17.95         18.05
# 8        18.70         18.35         17.90         18.00
# 9        18.60         18.30         17.85         17.95
# 10       18.50         18.25         17.80         17.90
# 11       18.90         18.20         17.75         17.85
# 12       18.80         18.15         18.70         18.80
# 13       18.70         18.10         18.65         18.75
# 14       18.50         18.05         18.60         18.70
# 15       19.30         18.00         18.55         18.65
# 16       18.40         17.95         18.50         18.60
# 17       18.90         17.90         18.45         18.55
# 18       18.25         17.85         18.40         18.50
# 19       18.95         17.80         18.35         18.45
# 20       18.30         17.75         18.30         18.40
# 22        2.00          1.80          1.35          1.45
# 23        1.90          1.75          1.30          1.40
# 24        1.80          1.70          1.25          1.35
# 25        1.70          1.65          1.20          1.30
# 26        1.60          1.60          1.15          1.25
# 27        1.50          1.55          1.10          1.20
# 28        1.40          1.50          1.05          1.15
# 29        1.80          1.45          1.00          1.10
# 30        1.70          1.40          0.95          1.05
# 31        1.60          1.35          0.90          1.00
# ..         ...           ...           ...           ...
# 200       8.55          7.85          7.40          7.50
# 201       8.45          7.80          8.35          8.45
# 202       8.35          7.75          8.30          8.40
# 203       8.15          7.70          8.25          8.35
# 204       8.95          7.65          8.20          8.30
# 205       8.05          7.60          8.15          8.25
# 206       8.55          7.55          8.10          8.20
# 207       7.90          7.50          8.05          8.15
# 208       8.60          7.45          8.00          8.10
# 209       7.95          7.40          7.95          8.05
# 211       6.27          6.07          5.62          5.72
# 212       6.27          6.02          5.57          5.67
# 213       6.27          5.97          5.52          5.62
# 214       6.27          5.92          5.47          5.57
# 215       6.27          5.87          5.42          5.52
# 216       6.27          5.82          5.37          5.47
# 217       6.27          5.77          5.32          5.42
# 218       6.27          5.72          5.27          5.37
# 219       6.27          5.67          5.22          5.32
# 220       6.27          5.62          5.17          5.27
# 221       6.27          5.57          5.12          5.22
# 222       6.27          5.52          6.07          6.17
# 223       6.27          5.47          6.02          6.12
# 224       6.27          5.42          5.97          6.07
# 225       6.27          5.37          5.92          6.02
# 226       6.27          5.32          5.87          5.97
# 227       6.27          5.27          5.82          5.92
# 228       6.27          5.22          5.77          5.87
# 229       6.27          5.17          5.72          5.82
# 230       6.27          5.12          5.67          5.77
#
# [220 rows x 8 columns]

# %%
# mais visualização, apagar depois

dados.tail()
# Out:
#       ITEM REFORMA DA PRAÇA MUNICIPAL SÃO JOÃO BATISTA UND.  QUANT.  \
# 226  11.16                    Grama batatais em placas   m²    35.0
# 227  11.17                    Grama batatais em placas   m²    36.0
# 228  11.18                    Grama batatais em placas   m²    37.0
# 229  11.19                    Grama batatais em placas   m²    38.0
# 230  11.20                    Grama batatais em placas   m²    39.0
#
#     PRECO_UNIT  PRECO_UNIT_1  PRECO_UNIT_2  PRECO_UNIT_3
# 226       6.27          5.32          5.87          5.97
# 227       6.27          5.27          5.82          5.92
# 228       6.27          5.22          5.77          5.87
# 229       6.27          5.17          5.72          5.82
# 230       6.27          5.12          5.67          5.77

# %%
# a quinta coluna é o preço contido no edital
# aqui chamamos de PRECO_UNIT
qntEmp = dados.shape[1] - 5
qntItems = dados.shape[0]

print(f'{qntEmp} , {qntItems}')
# Out:
# 3 , 220

# %%
# convertemos pra float, pois essa coluna não estava sendo identificada (type = object)
dados["PRECO_UNIT"] = dados.PRECO_UNIT.astype(float)

# apenas pra visualizar, apagar depois
dados["PRECO_UNIT"]
# Out:
# 1      18.90
# 2      18.80
# 3      18.70
# 4      18.60
# 5      18.50
# 6      18.40
# 7      18.30
# 8      18.70
# 9      18.60
# 10     18.50
# 11     18.90
# 12     18.80
# 13     18.70
# 14     18.50
# 15     19.30
# 16     18.40
# 17     18.90
# 18     18.25
# 19     18.95
# 20     18.30
# 22      2.00
# 23      1.90
# 24      1.80
# 25      1.70
# 26      1.60
# 27      1.50
# 28      1.40
# 29      1.80
# 30      1.70
# 31      1.60
#        ...
# 200     8.55
# 201     8.45
# 202     8.35
# 203     8.15
# 204     8.95
# 205     8.05
# 206     8.55
# 207     7.90
# 208     8.60
# 209     7.95
# 211     6.27
# 212     6.27
# 213     6.27
# 214     6.27
# 215     6.27
# 216     6.27
# 217     6.27
# 218     6.27
# 219     6.27
# 220     6.27
# 221     6.27
# 222     6.27
# 223     6.27
# 224     6.27
# 225     6.27
# 226     6.27
# 227     6.27
# 228     6.27
# 229     6.27
# 230     6.27
# Name: PRECO_UNIT, Length: 220, dtype: float64

# %%
# teste, remover depois
tabelaDiferencaAbs = abs(dados['PRECO_UNIT_1'] - dados['PRECO_UNIT_2'])

# %%
# teste, remover depois
tabelaDiferencaAbs.value_counts()
# Out:
# 0.45    27
# 0.55    24
# 0.45    23
# 0.55    18
# 0.45    16
# 0.55    14
# 0.45     9
# 0.45     9
# 0.45     9
# 0.45     9
# 0.55     7
# 0.55     7
# 0.55     7
# 0.45     6
# 0.55     6
# 0.55     6
# 0.45     5
# 0.45     4
# 0.55     3
# 0.55     3
# 0.45     2
# 0.45     2
# 0.55     2
# 0.55     2
# dtype: int64

# %%
# A coluna com os preços do edital se chama PRECO_UNIT
# As colunas com os preços das empresas se chamam PRECO_UNIT_#, com # o numero da empresa
# começando com 1.

# aqui geramos uma lista vazia que conterá 
# os nomes das Pandas.Series para as empresas 
# que estão se aplicando no Edital
lista_de_series_empresas = ['']*qntEmp

# aqui inserimos os nomes das series pandas
for i in range(1,qntEmp+1):
    print(i)
    serie_title = f'PRECO_UNIT_{i}'
    lista_de_series_empresas[i-1] = serie_title
    print(lista_de_series_empresas[i-1])
# Out:
# 1
# PRECO_UNIT_1
# 2
# PRECO_UNIT_2
# 3
# PRECO_UNIT_3

# %%
# Pra visualizar, apagar depois
lista_de_series_empresas
# Out:
# ['PRECO_UNIT_1', 'PRECO_UNIT_2', 'PRECO_UNIT_3']

# %%
tabela = []*qntEmp # tabela é uma lista de pandas.Series

# %%
tabela # Pra visualizar, apagar depois
# Out:
# []

# %%
#iremos copiar a lista de nomes
# pra poder usar o metodo list.remove(_)
# sem alterar a lista original
copia_da_lista_empresas = lista_de_series_empresas.copy()
print(copia_da_lista_empresas)
# Out:
# ['PRECO_UNIT_1', 'PRECO_UNIT_2', 'PRECO_UNIT_3']

# %%
tabela_diff_abs_empresas = pd.DataFrame()
tabela_diff_perc_empresas = pd.DataFrame()

for s_t in lista_de_series_empresas: # s_t stands for series_title    
    # remove o primeiro elemento da lista
    copia_da_lista_empresas.remove(s_t)
    for s_t2 in copia_da_lista_empresas:
        #gerando as colunas de diferenças absolutas
        coluna1 = abs(dados[s_t] - dados[s_t2])
        titulo_da_coluna1 = f'{s_t} - {s_t2}'
        
        #gerando as colunas de diferenças relativas
        coluna2 = 100*abs((dados[s_t] - dados[s_t2])/dados[s_t])
        titulo_da_coluna2 = f'{s_t} e {s_t2}'
        
        tabela_diff_abs_empresas[titulo_da_coluna1] = coluna1 
        tabela_diff_perc_empresas[titulo_da_coluna2] = coluna2

    
    
    """
    print(copia_da_lista_empresas)
    print(lista_de_series_empresas)
    #
    print(s_t)
    """

# %%
# visualização, apagar depois
tabela_diff_abs_empresas
# Out:
#      PRECO_UNIT_1 - PRECO_UNIT_2  PRECO_UNIT_1 - PRECO_UNIT_3  \
# 1                           0.45                         0.35
# 2                           0.45                         0.35
# 3                           0.45                         0.35
# 4                           0.45                         0.35
# 5                           0.45                         0.35
# 6                           0.45                         0.35
# 7                           0.45                         0.35
# 8                           0.45                         0.35
# 9                           0.45                         0.35
# 10                          0.45                         0.35
# 11                          0.45                         0.35
# 12                          0.55                         0.65
# 13                          0.55                         0.65
# 14                          0.55                         0.65
# 15                          0.55                         0.65
# 16                          0.55                         0.65
# 17                          0.55                         0.65
# 18                          0.55                         0.65
# 19                          0.55                         0.65
# 20                          0.55                         0.65
# 22                          0.45                         0.35
# 23                          0.45                         0.35
# 24                          0.45                         0.35
# 25                          0.45                         0.35
# 26                          0.45                         0.35
# 27                          0.45                         0.35
# 28                          0.45                         0.35
# 29                          0.45                         0.35
# 30                          0.45                         0.35
# 31                          0.45                         0.35
# ..                           ...                          ...
# 200                         0.45                         0.35
# 201                         0.55                         0.65
# 202                         0.55                         0.65
# 203                         0.55                         0.65
# 204                         0.55                         0.65
# 205                         0.55                         0.65
# 206                         0.55                         0.65
# 207                         0.55                         0.65
# 208                         0.55                         0.65
# 209                         0.55                         0.65
# 211                         0.45                         0.35
# 212                         0.45                         0.35
# 213                         0.45                         0.35
# 214                         0.45                         0.35
# 215                         0.45                         0.35
# 216                         0.45                         0.35
# 217                         0.45                         0.35
# 218                         0.45                         0.35
# 219                         0.45                         0.35
# 220                         0.45                         0.35
# 221                         0.45                         0.35
# 222                         0.55                         0.65
# 223                         0.55                         0.65
# 224                         0.55                         0.65
# 225                         0.55                         0.65
# 226                         0.55                         0.65
# 227                         0.55                         0.65
# 228                         0.55                         0.65
# 229                         0.55                         0.65
# 230                         0.55                         0.65
#
#      PRECO_UNIT_2 - PRECO_UNIT_3
# 1                            0.1
# 2                            0.1
# 3                            0.1
# 4                            0.1
# 5                            0.1
# 6                            0.1
# 7                            0.1
# 8                            0.1
# 9                            0.1
# 10                           0.1
# 11                           0.1
# 12                           0.1
# 13                           0.1
# 14                           0.1
# 15                           0.1
# 16                           0.1
# 17                           0.1
# 18                           0.1
# 19                           0.1
# 20                           0.1
# 22                           0.1
# 23                           0.1
# 24                           0.1
# 25                           0.1
# 26                           0.1
# 27                           0.1
# 28                           0.1
# 29                           0.1
# 30                           0.1
# 31                           0.1
# ..                           ...
# 200                          0.1
# 201                          0.1
# 202                          0.1
# 203                          0.1
# 204                          0.1
# 205                          0.1
# 206                          0.1
# 207                          0.1
# 208                          0.1
# 209                          0.1
# 211                          0.1
# 212                          0.1
# 213                          0.1
# 214                          0.1
# 215                          0.1
# 216                          0.1
# 217                          0.1
# 218                          0.1
# 219                          0.1
# 220                          0.1
# 221                          0.1
# 222                          0.1
# 223                          0.1
# 224                          0.1
# 225                          0.1
# 226                          0.1
# 227                          0.1
# 228                          0.1
# 229                          0.1
# 230                          0.1
#
# [220 rows x 3 columns]

# %%
# visualização, apagar depois
tabela_diff_perc_empresas
# Out:
#      PRECO_UNIT_1 e PRECO_UNIT_2  PRECO_UNIT_1 e PRECO_UNIT_3  \
# 1                       2.406417                     1.871658
# 2                       2.412869                     1.876676
# 3                       2.419355                     1.881720
# 4                       2.425876                     1.886792
# 5                       2.432432                     1.891892
# 6                       2.439024                     1.897019
# 7                       2.445652                     1.902174
# 8                       2.452316                     1.907357
# 9                       2.459016                     1.912568
# 10                      2.465753                     1.917808
# 11                      2.472527                     1.923077
# 12                      3.030303                     3.581267
# 13                      3.038674                     3.591160
# 14                      3.047091                     3.601108
# 15                      3.055556                     3.611111
# 16                      3.064067                     3.621170
# 17                      3.072626                     3.631285
# 18                      3.081232                     3.641457
# 19                      3.089888                     3.651685
# 20                      3.098592                     3.661972
# 22                     25.000000                    19.444444
# 23                     25.714286                    20.000000
# 24                     26.470588                    20.588235
# 25                     27.272727                    21.212121
# 26                     28.125000                    21.875000
# 27                     29.032258                    22.580645
# 28                     30.000000                    23.333333
# 29                     31.034483                    24.137931
# 30                     32.142857                    25.000000
# 31                     33.333333                    25.925926
# ..                           ...                          ...
# 200                     5.732484                     4.458599
# 201                     7.051282                     8.333333
# 202                     7.096774                     8.387097
# 203                     7.142857                     8.441558
# 204                     7.189542                     8.496732
# 205                     7.236842                     8.552632
# 206                     7.284768                     8.609272
# 207                     7.333333                     8.666667
# 208                     7.382550                     8.724832
# 209                     7.432432                     8.783784
# 211                     7.413509                     5.766063
# 212                     7.475083                     5.813953
# 213                     7.537688                     5.862647
# 214                     7.601351                     5.912162
# 215                     7.666099                     5.962521
# 216                     7.731959                     6.013746
# 217                     7.798960                     6.065858
# 218                     7.867133                     6.118881
# 219                     7.936508                     6.172840
# 220                     8.007117                     6.227758
# 221                     8.078995                     6.283662
# 222                     9.963768                    11.775362
# 223                    10.054845                    11.882998
# 224                    10.147601                    11.992620
# 225                    10.242086                    12.104283
# 226                    10.338346                    12.218045
# 227                    10.436433                    12.333966
# 228                    10.536398                    12.452107
# 229                    10.638298                    12.572534
# 230                    10.742187                    12.695312
#
#      PRECO_UNIT_2 e PRECO_UNIT_3
# 1                       0.547945
# 2                       0.549451
# 3                       0.550964
# 4                       0.552486
# 5                       0.554017
# 6                       0.555556
# 7                       0.557103
# 8                       0.558659
# 9                       0.560224
# 10                      0.561798
# 11                      0.563380
# 12                      0.534759
# 13                      0.536193
# 14                      0.537634
# 15                      0.539084
# 16                      0.540541
# 17                      0.542005
# 18                      0.543478
# 19                      0.544959
# 20                      0.546448
# 22                      7.407407
# 23                      7.692308
# 24                      8.000000
# 25                      8.333333
# 26                      8.695652
# 27                      9.090909
# 28                      9.523810
# 29                     10.000000
# 30                     10.526316
# 31                     11.111111
# ..                           ...
# 200                     1.351351
# 201                     1.197605
# 202                     1.204819
# 203                     1.212121
# 204                     1.219512
# 205                     1.226994
# 206                     1.234568
# 207                     1.242236
# 208                     1.250000
# 209                     1.257862
# 211                     1.779359
# 212                     1.795332
# 213                     1.811594
# 214                     1.828154
# 215                     1.845018
# 216                     1.862197
# 217                     1.879699
# 218                     1.897533
# 219                     1.915709
# 220                     1.934236
# 221                     1.953125
# 222                     1.647446
# 223                     1.661130
# 224                     1.675042
# 225                     1.689189
# 226                     1.703578
# 227                     1.718213
# 228                     1.733102
# 229                     1.748252
# 230                     1.763668
#
# [220 rows x 3 columns]
